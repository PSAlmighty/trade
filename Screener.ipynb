# %%
import pandas as pd
import requests
import io

# %%
nse_referer = "https://www.nseindia.com/products/content/equities/equities/eq_security.htm"
chrome_agent = "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36"
headers = {'User-Agent': chrome_agent, 'referer':nse_referer}
data = requests.get("https://www.nseindia.com/products/content/sec_bhavdata_full.csv", headers = headers)

# %%
yesterday = pd.read_csv(io.StringIO(data.content.decode('utf-8')))

# %%
yesterday
# Out:
#           SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0      20MICRONS      EQ   19-Sep-2018        48.60        48.65        49.80
# 1     21STCENMGM      EQ   19-Sep-2018        32.35        31.95        32.00
# 2     3IINFOTECH      EQ   19-Sep-2018         4.00         4.20         4.20
# 3        3MINDIA      EQ   19-Sep-2018     25270.25     25200.00     25494.85
# 4         3PLAND      BE   19-Sep-2018        12.65        12.65        12.65
# 5         5PAISA      EQ   19-Sep-2018       285.55       285.30       289.70
# 6        63MOONS      EQ   19-Sep-2018        85.05        85.70        86.90
# 7        8KMILES      BE   19-Sep-2018       247.80       235.45       260.15
# 8       A2ZINFRA      EQ   19-Sep-2018        19.15        19.50        19.50
# 9          AARON      SM   19-Sep-2018        39.00        41.00        41.80
# 10    AARTIDRUGS      EQ   19-Sep-2018       629.45       630.10       640.00
# ...

# %%
yesterday.rename(columns=lambda x: x.strip(), inplace = True)
yesterday.columns
# Out:
# Index(['SYMBOL', 'SERIES', 'DATE1', 'PREV_CLOSE', 'OPEN_PRICE', 'HIGH_PRICE',
#        'LOW_PRICE', 'LAST_PRICE', 'CLOSE_PRICE', 'AVG_PRICE', 'TTL_TRD_QNTY',
#        'TURNOVER_LACS', 'NO_OF_TRADES', 'DELIV_QTY', 'DELIV_PER'],
#       dtype='object')

# %%
yesterday["SYMBOL"].loc[yesterday["LOW_PRICE"] >= yesterday["OPEN_PRICE"]]
# Out:
# 7          8KMILES
# 49         AIONJSW
# 55           AKASH
# 70         ALMONDZ
# 76       AMBANIORG
# 87          ANGIND
# 89      ANKITMETAL
# 95      APCOTEXIND
# 98          APLLTD
# 118     ASAHIINDIA
# 152            AVG
# 177      BANARISUG
# 203        BGLOBAL
# 207     BHAGYAPROP
# 220      BILENERGY
# 225     BIOFILCHEM
# 231       BLISSGVS
# 236       BLUEDART
# 237       BLUEDART
# 240          BOHRA
# 257       BSLNIFTY
# 263        CALSOFT
# 272       CAPTRUST
# 277     CASTROLIND
# 303      CHROMATIC
# 313     CNOVAPETRO
# 314      COALINDIA
# 321     CONSOFINVT
# 333         CRISIL
# 334       CRMFGETF
#            ...
# 1667    TANTIACONS
# 1668     TARACHAND
# 1669    TARAJEWELS
# 1670       TARAPUR
# 1688           TCI
# 1689    TCIDEVELOP
# 1706           TFL
# 1718         TIFIN
# 1727    TIPSINDLTD
# 1729      TIRUPATI
# 1730    TIRUPATIFL
# 1753         TULSI
# 1777     UNITEDTEA
# 1778         UNITY
# 1782      USHAMART
# 1784    UTIFEFRGR4
# ...
