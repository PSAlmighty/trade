# %%
from trader import *

# %%
plot_ohlc("reliance")

# %%
long_pl("reliance",30)
# Out:
# Buy Price	: 1233.25
#
# BEP	: 1234.15 	Net :  0.87
# 10 Rs	: 1234.5 	Net :  11.37
# 50 Rs	: 1235.8 	Net :  50.36
